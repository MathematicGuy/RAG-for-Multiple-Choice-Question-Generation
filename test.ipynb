# %% [markdown]
# ![image.png](attachment:image.png)
#
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(d):
    re = 0
    va = d[0]
    ind = 1

    while ind < len(d):
        if d[ind] < va:
            va = d[ind]
            re = ind

        ind += 1

    return re

f([2,5,9,12])

# %%
for i in range(1, 6, 2):
    if i == 3:
        continue
    print(i * 2)
# Out:
# 2
# 10

# %%
def fac(n):
    res = 1
    for i in range(2, n +1):
        print(i)
        res = res * i # 2, 6,
    return res #

fac(3)
# Out:
# 2
# 3
# 6

# %%
for i in range(3):
    print(i)
    r = 0
    r = r + i*i
# print(r)
# Out:
# 0
# 1
# 2

# %%
data = [1,2,8,7]
print(len(data))
rel = [x if x%2==0 else 0 for x in data if x > 4]
print(rel)
# Out:
# 4
# [8, 0]

# %%
rel  =0
length = 4
data = [2,8,6,4]
for i in range(4):
    if i%2 == 1:
        rel = rel + data[i]
print(rel)
print(length)
print(rel / length)
# Out:
# 12
# 4
# 3.0

# %%
d1 = [1,2,3]
d2 = d1
d3 = d1.copy()

d1[0] = 9
print(d2, d3)
# Out:
# [9, 2, 3] [1, 2, 3]

# %%
def print_matrix(matrix):
    for i in range(h):
        for j in range(w):
            print(matrix[i][j], end='')
        print()

w = 2
h  = 3
m = [[0,0], [0, 0], [0,0]]

for i  in range(h):
    for j in range(w):
        m[i][j] = i*w+ j
print_matrix(m)
# Out:
# 01
# 23
# 45

# %%
d = [1,2]
d.extend([4, 2])
print(d)
# Out:
# [1, 2, 4, 2]

# %%
class Cat:
    def des(age, this):
        print(this)

c = Cat()
c.des(3)
# Out:
# 3

# %%
class Ani:
    def __init__(self):
        self.age = 2


class C(Ani):
    def __init__(self):
        print(1)

    def des(self):
        print(self.age)


jon = C()
jon.des()
# Out:
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 15
#      11         print(self.age)
#      14 jon = C()
# ---> 15 jon.des()
#
# Cell In[45], line 11, in C.des(self)
#      10 def des(self):
# ---> 11     print(self.age)
#
# AttributeError: 'C' object has no attribute 'age'

# %%
class C:
    def des(age, self):
        age.__age = 9
        print(age.__age, self)

ca = C()
ca.des(1)
# Out:
# 9 1

# %%
class Ani:
    def __init__(self):
        self._age = 1.4



class C(Ani):
    def __init__(self):
        super().__init__()

    def des(self):
        print(self._age)


jon = C()
jon.des()
# Out:
# 1.4

# %% [markdown]
# ![image.png](attachment:image.png)
